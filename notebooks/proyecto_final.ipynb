# %%
import pandas as pd 
import numpy as np
import funciones as fs
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# EMPEZAMOS GENERANDO EL DF CON EL QUE TRABAJAREMOS

# %%
df = pd.read_excel("data/european_cars.xlsx")

# %%
fs.chequeo_inicial(df)
# Out:
# Shape:
# (6000, 25)
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Model Name                 6000 non-null   object
#  1   Brand                      6000 non-null   object
#  2   Body Type                  6000 non-null   object
#  3   Segment                    6000 non-null   object
#  4   Usable Battery (kWh)       6000 non-null   float64
#  5   Real Range (km)            6000 non-null   int64
#  6   Efficiency (Wh/km)         6000 non-null   float64
#  7   0–100 km/h (s)             6000 non-null   float64
#  8   Top Speed (km/h)           6000 non-null   int64
#  9   Towing Capacity (kg)       6000 non-null   int64
#  10  Price (EUR)                6000 non-null   int64
#  11  Charging Time (min)        6000 non-null   int64
#  12  Max Charging Power (kW)    6000 non-null   int64
# ...

# %% [markdown]
# HABIENDO CHEQUEADO QUE EL DF NO TIENE VALORES NULOS Y LOS TIPO DE DATO SON CORRECTOS, ELIMINAREMOS LAS COLUMNAS QUE NO UTILIZAREMOS EN ESTE ANALISIS Y A SU VEZ RENOMBRAREMOS LAS COLUMNAS PARA FACILITAR EL TRABAJO.

# %%
df_master = fs.config_columns(df)

# %%
df_master.columns
# Out:
# Index(['model_name', 'brand', 'body_type', 'segment', 'price_eur',
#        'maintenance_cost_year', 'seating_capacity', 'boot_capacity_l',
#        'safety_rating', 'energy_cost_100km', 'powertrain_type', 'fuel_type'],
#       dtype='object')

# %%
df_master["powertrain_type"].value_counts()
# Out:
# powertrain_type
# Hybrid    1668
# Petrol    1666
# Diesel    1666
# EV        1000
# Name: count, dtype: int64

# %% [markdown]
# EN PRIMER LUGAR VAMOS A CREAR UNA NUEVA VARIABLE SUSTENTABLE QUE CONTENGA LOS COCHES QUE SU FUEL-TYPE SEA HIBRIDA O EV.

# %%
df_master = fs.coches_sustentables(df_master)
df_master
# Out:
#                       model_name          brand  body_type    segment  \
# 0                     Kia R7 Pro            Kia      Sedan          D
# 1                   Fiat T-Class           Fiat  Crossover          D
# 2                       Mini P8x           Mini      Wagon          B
# 3                      Honda F3x          Honda  Hatchback          A
# 4                     BMW E8 Pro            BMW  Hatchback          C
# ...                          ...            ...        ...        ...
# 5995  Renault Twingo E-Tech 2022        Renault      Wagon    Premium
# 5996                 MG MG5 2024             MG  Crossover  Mid-Range
# 5997            Toyota bZ4X 2025         Toyota      Coupe  Mid-Range
# 5998  Mercedes-Benz EQE 500 2023  Mercedes-Benz  Crossover     Luxury
# 5999              Fiat 500e 2023           Fiat      Wagon    Economy
#
#       price_eur  maintenance_cost_year  seating_capacity  boot_capacity_l  \
# ...

# %%
df_master['sustainable'].mean()
# Out:
# np.float64(0.44466666666666665)

# %% [markdown]
# POR OTRO LADO, VAMOS A CREAR UNA COLUMNA FILTRANDO AQUELLOS COCHES QUE CUMPLEN LAS CARACTERISTICAS GENERALES PARA SER "FAMILIAR"

# %%
df_master = fs.familiares(df_master)
df_master
# Out:
#                       model_name          brand  body_type    segment  \
# 0                     Kia R7 Pro            Kia      Sedan          D
# 1                   Fiat T-Class           Fiat  Crossover          D
# 2                       Mini P8x           Mini      Wagon          B
# 3                      Honda F3x          Honda  Hatchback          A
# 4                     BMW E8 Pro            BMW  Hatchback          C
# ...                          ...            ...        ...        ...
# 5995  Renault Twingo E-Tech 2022        Renault      Wagon    Premium
# 5996                 MG MG5 2024             MG  Crossover  Mid-Range
# 5997            Toyota bZ4X 2025         Toyota      Coupe  Mid-Range
# 5998  Mercedes-Benz EQE 500 2023  Mercedes-Benz  Crossover     Luxury
# 5999              Fiat 500e 2023           Fiat      Wagon    Economy
#
#       price_eur  maintenance_cost_year  seating_capacity  boot_capacity_l  \
# ...

# %%
df_master["coche_familiar"].value_counts(normalize=True)
# Out:
# coche_familiar
# 0    0.572
# 1    0.428
# Name: proportion, dtype: float64

# %% [markdown]
# EL 38% DE LOS COCHES QUE SE COMERCIALIZAN LOS PODEMOS CONSIDERAR "FAMILIAR"

# %%
df_master[df_master['coche_familiar']==1]['sustainable'].mean()
# Out:
# np.float64(0.3987538940809969)

# %% [markdown]
# EL 40% DE LOS COCHES FAMILIARES SON ELECTRICOS O HIBRIDOS (ETIQUETAS "0" O "ECO")

# %%
df_master = fs.familiares(df_master, min_boot_l=500)
df_master['coche_familiar'].mean()
# Out:
# np.float64(0.38)

# %% [markdown]
# POR ULTIMO CREAMOS UNA VARIABLE QUE ESTABLEZCA EL COSTO ANUAL DE MANTENIMIENTO DE CADA VEHICULO, ASUMIENDO COMO MEDIA DE KM RECORRIDOS POR AÑO 15000KM

# %%
df_master = fs.costes_anuales(df_master)
df_master
# Out:
#                       model_name          brand  body_type    segment  \
# 0                     Kia R7 Pro            Kia      Sedan          D
# 1                   Fiat T-Class           Fiat  Crossover          D
# 2                       Mini P8x           Mini      Wagon          B
# 3                      Honda F3x          Honda  Hatchback          A
# 4                     BMW E8 Pro            BMW  Hatchback          C
# ...                          ...            ...        ...        ...
# 5995  Renault Twingo E-Tech 2022        Renault      Wagon    Premium
# 5996                 MG MG5 2024             MG  Crossover  Mid-Range
# 5997            Toyota bZ4X 2025         Toyota      Coupe  Mid-Range
# 5998  Mercedes-Benz EQE 500 2023  Mercedes-Benz  Crossover     Luxury
# 5999              Fiat 500e 2023           Fiat      Wagon    Economy
#
#       price_eur  maintenance_cost_year  seating_capacity  boot_capacity_l  \
# ...

# %%
df_master.columns
# Out:
# Index(['model_name', 'brand', 'body_type', 'segment', 'price_eur',
#        'maintenance_cost_year', 'seating_capacity', 'boot_capacity_l',
#        'safety_rating', 'energy_cost_100km', 'powertrain_type', 'fuel_type',
#        'sustainable', 'coche_familiar', 'costo_energia_anual',
#        'costo_total_anual'],
#       dtype='object')

# %% [markdown]
# YA CON EL DF ARMADO CON LAS COLUMNAS QUE NECESITAREMOS POR LO QUE GENERAMOS EL NUEVO .CSV PARA PASAR A SEGUIR EL ANALISIS EN SQL.

# %%
df_master.to_csv("cars_final.csv", index=False)

# %% [markdown]
# PROCEDEMOS A CONECTARNOS A SQL.

# %%
import mysql.connector

# %%
import getpass 
password = getpass.getpass()

# %%
conn = mysql.connector.connect(host='localhost',
                        user='root',
                        passwd=password)

# %%
cursor = conn.cursor()

cursor

# %% [markdown]
# UNA VEZ CONECTADOS, CREAMOS EL DATABASE

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS final_project;")

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd=password,
    database="final_project"
)
cursor = conn.cursor()

# %% [markdown]
# CREAMOS LA TABLA DENTRO DEL DATABASE

# %%
from sqlalchemy import create_engine

engine = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/final_project")

df_master.to_sql("cars", con=engine, if_exists="replace", index=False)
# Out:
# 6000

# %% [markdown]
# CHEQUEAMOS QUE SE HAYA CREADO CORRECTAMENTE Y NO SE HAYAN ELIMINADO FILAS

# %%
pd.read_sql("SELECT COUNT(*) AS n FROM cars;", con=engine)
# Out:
#       n
# 0  6000

# %% [markdown]
# HABIENDO REALIZADO LAS QUERIES, PROCEDEMOS A GENERAR DOS NUEVAS COLUMNAS PARA QUE PODAMOS TRABAJAR EN TABLEAU: "COSTO TOTAL 5 AÑOS" y "PROP CT 5Y - INGRESO FAMILIAR"

# %%
df_master["cto_5y"] = df_master["price_eur"] + 5 * df_master["costo_total_anual"]

# %%
income_ref = 34716

df_master["prop_cto_ingreso"] = df_master["cto_5y"] / income_ref

# %%
df_master.columns
# Out:
# Index(['model_name', 'brand', 'body_type', 'segment', 'price_eur',
#        'maintenance_cost_year', 'seating_capacity', 'boot_capacity_l',
#        'safety_rating', 'energy_cost_100km', 'powertrain_type', 'fuel_type',
#        'sustainable', 'coche_familiar', 'costo_energia_anual',
#        'costo_total_anual', 'cto_5y', 'prop_cto_ingreso'],
#       dtype='object')

# %% [markdown]
# UNA VEZ GENERADAS LAS DOS COLUMNAS, CREAMOS UN NUEVO .CSV y PROCEDEMOS A TRABAJAR EN TABLEAU

# %%
df_master.to_csv("cars_analysis_final.csv", index=False)
